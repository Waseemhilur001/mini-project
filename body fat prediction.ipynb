# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bodyfat=pd.read_csv('C:/Users/Public/bodyfat.csv')

# %%
bodyfat
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
bodyfat.shape
# Out:
# (252, 15)

# %%
bodyfat.tail()
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9

# %%
data=bodyfat.drop(['Neck','Chest','Age','Density','Height','Abdomen','Hip','Thigh','Knee','Ankle','Biceps','Forearm','Wrist'],axis=1)

# %%
data
# Out:
#      BodyFat  Weight
# 0       12.3  154.25
# 1        6.1  173.25
# 2       25.3  154.00
# 3       10.4  184.75
# 4       28.7  184.25
# ..       ...     ...
# 247     11.0  134.25
# 248     33.6  201.00
# 249     29.3  186.75
# 250     26.0  190.75
# 251     31.9  207.50
#
# [252 rows x 2 columns]

# %%
x=data.iloc[:,0].values.reshape(-1,1)
y=data.iloc[:,-1].values.reshape(-1,1)

# %%
x
# Out:
# array([[12.3],
#        [ 6.1],
#        [25.3],
#        [10.4],
#        [28.7],
#        [20.9],
#        [19.2],
#        [12.4],
#        [ 4.1],
#        [11.7],
#        [ 7.1],
#        [ 7.8],
#        [20.8],
#        [21.2],
#        [22.1],
#        [20.9],
#        [29. ],
#        [22.9],
#        [16. ],
#        [16.5],
#        [19.1],
#        [15.2],
#        [15.6],
#        [17.7],
#        [14. ],
#        [ 3.7],
#        [ 7.9],
#        [22.9],
#        [ 3.7],
#        [ 8.8],
#        [11.9],
#        [ 5.7],
#        [11.8],
#        [21.3],
#        [32.3],
#        [40.1],
#        [24.2],
#        [28.4],
#        [35.2],
#        [32.6],
#        [34.5],
#        [32.9],
#        [31.6],
#        [32. ],
#        [ 7.7],
#        [13.9],
#        [10.8],
#        [ 5.6],
#        [13.6],
#        [ 4. ],
#        [10.2],
#        [ 6.6],
#        [ 8. ],
#        [ 6.3],
#        [ 3.9],
#        [22.6],
#        [20.4],
#        [28. ],
# ...

# %%
y
# Out:
# array([[154.25],
#        [173.25],
#        [154.  ],
#        [184.75],
#        [184.25],
#        [210.25],
#        [181.  ],
#        [176.  ],
#        [191.  ],
#        [198.25],
#        [186.25],
#        [216.  ],
#        [180.5 ],
#        [205.25],
#        [187.75],
#        [162.75],
#        [195.75],
#        [209.25],
#        [183.75],
#        [211.75],
#        [179.  ],
#        [200.5 ],
#        [140.25],
#        [148.75],
#        [151.25],
#        [159.25],
#        [131.5 ],
#        [148.  ],
#        [133.25],
#        [160.75],
#        [182.  ],
#        [160.25],
#        [168.  ],
#        [218.5 ],
#        [247.25],
#        [191.75],
#        [202.25],
#        [196.75],
#        [363.15],
#        [203.  ],
#        [262.75],
#        [205.  ],
#        [217.  ],
#        [212.  ],
#        [125.25],
#        [164.25],
#        [133.5 ],
#        [148.5 ],
#        [135.75],
#        [127.5 ],
#        [158.25],
#        [139.25],
# ...

# %%
plt.scatter(x,y)
plt.xlabel('BodyFat')
plt.ylabel('Weight')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_test.shape
# Out:
# (51, 1)

# %%
x_train.shape
# Out:
# (201, 1)

# %%
y_train.shape
# Out:
# (201, 1)

# %%
y_test.shape
# Out:
# (51, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm
# Out:
# LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(x_test)

# %%
y_predict
# Out:
# array([[165.75582685],
#        [195.93286888],
#        [145.98466139],
#        [182.19711182],
#        [159.30418338],
#        [188.85687282],
#        [193.4354585 ],
#        [192.18675332],
#        [193.4354585 ],
#        [196.14098641],
#        [192.18675332],
#        [171.79123526],
#        [184.27828713],
#        [182.40522935],
#        [174.0805281 ],
#        [167.83700216],
#        [174.28864563],
#        [141.19795817],
#        [160.55288857],
#        [163.25841648],
#        [182.19711182],
#        [168.66947229],
#        [201.96827728],
#        [186.35946244],
#        [180.7402891 ],
#        [206.13062791],
#        [148.27395423],
#        [186.77569751],
#        [185.52699232],
#        [198.84651432],
#        [202.59262988],
#        [196.34910394],
#        [198.01404419],
#        [163.67465154],
#        [211.12544866],
#        [169.29382488],
#        [188.85687282],
#        [183.23769947],
#        [172.20747032],
#        [163.46653401],
# ...

# %%
check=pd.DataFrame(x_test,columns=['Bodyfat'])

# %%
check['actual Weight']=y_test

# %%
check[' Weight Predicted']=y_predit

# %%
check
# Out:
#     Bodyfat  actual Weight   Weight Predicted
# 0      12.5         136.50         165.755827
# 1      27.0         170.75         195.932869
# 2       3.0         152.25         145.984661
# 3      20.4         173.75         182.197112
# 4       9.4         152.25         159.304183
# 5      23.6         170.75         188.856873
# 6      25.8         191.00         193.435459
# 7      25.2         198.50         192.186753
# 8      25.8         178.00         193.435459
# 9      27.1         186.00         196.140986
# 10     25.2         223.00         192.186753
# 11     15.4         175.50         171.791235
# 12     21.4         168.50         184.278287
# 13     20.5         202.25         182.405229
# 14     16.5         156.75         174.080528
# 15     13.5         125.00         167.837002
# 16     16.6         208.75         174.288646
# 17      0.7         125.75         141.197958
# 18     10.0         182.50         160.552889
# ...

# %%
check
# Out:
#     Bodyfat  actual Weight   Weight Predicted
# 0      12.5         136.50         165.755827
# 1      27.0         170.75         195.932869
# 2       3.0         152.25         145.984661
# 3      20.4         173.75         182.197112
# 4       9.4         152.25         159.304183
# 5      23.6         170.75         188.856873
# 6      25.8         191.00         193.435459
# 7      25.2         198.50         192.186753
# 8      25.8         178.00         193.435459
# 9      27.1         186.00         196.140986
# 10     25.2         223.00         192.186753
# 11     15.4         175.50         171.791235
# 12     21.4         168.50         184.278287
# 13     20.5         202.25         182.405229
# 14     16.5         156.75         174.080528
# 15     13.5         125.00         167.837002
# 16     16.6         208.75         174.288646
# 17      0.7         125.75         141.197958
# 18     10.0         182.50         160.552889
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mean_squared_error(y_test,y_predit)
# Out:
# 381.0166559646056

# %%
mean_absolute_error(y_test,y_predit)
# Out:
# 15.85153998219754

# %%
r2_score(y_test,y_predit)
# Out:
# 0.513096087078029

# %%
check.to_csv('C:/Users/Public/bodyfat.csv')
